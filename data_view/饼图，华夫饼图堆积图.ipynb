# %%
# Python matplotlib 绘制饼图
# 饼图常用场景
# 饼图可用在需要暂时各个部分构成比
# 饼图可反映一个维度各项指标占总体的占比情况
# 饼图适用在只看大体占比，不要数据精度的情况
# %pip install numpy matplotlib
import numpy as np
size = np.random.randint(0,100,5)
# 使用random.randint产生5个数值
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt\
 
plt.pie(size,labels=["a","b","c","d","e"])
 
plt.title("Pie1")

plt.show()

# %%
plt.pie(size,labels=["a","b","c","d","e"],
explode=[0,0.1,0,0,0],#突出显示
# 颜色列表可以由如下组成：
# 表示颜色的英文单词：如红色"red"
# 表示颜色单词的简称如：红色"r",黄色"y"
# RGB格式：十六进制格式如"#88c999";(r,g,b)元组形式
colors=("r","blue","#88c999",(1,1,0),"0.5"),radius=1.2)
plt.show()

# %%
# %pip install pywaffle
import matplotlib.pyplot as plt
from pywaffle import Waffle
# 首先将Waffle类传递给matplotlib.pyplot.figure函数的FigureClass参数，
# 然后通过设置matplotlib.pyplot.figure函数的参数即可完成华夫饼图的定制。
# Out:
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(
    FigureClass=Waffle,
    
    rows=10,
    columns=10,
    values=[48, 46, 6]
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values={'Cat1': 25, 'Cat2': 15, 'Cat3': 10},
    # 设置图例的位置
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    dpi=100
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    colors=("#232066", "#983D3D", "#DCB732"),
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    icons='child', icon_size=14, 
    icon_legend=True,
#     调整图的大小
    dpi=300,
)
plt.show()
# Out:
# <Waffle size 1920x1440 with 1 Axes>

# %%
#堆叠条形图

import matplotlib.pyplot as plt
import numpy as np
# 返回一个终点为4的排列
index = np.arange(4)  
data1 = np.array([1,5,6,3])
data2 = np.array([1,2,1,5])
data3 = np.array([4,8,9,4])

a = 0.3#定义宽度
plt.title('multi bar chart')
# plt.bar()：bar()函数用于绘制正常的柱状图
plt.bar(index, data1, a, color = 'pink', label = 'a', hatch = '/')#柱子填充符号。
plt.bar(index, data2, a, bottom = data1,           # 堆叠在第一个上方
        color = 'c', label = 'b')
plt.bar(index, data3, a, bottom = (data1 + data2), # 堆叠在第一个和第二个上方
        color = 'orange', alpha = 0.5,label = 'c')

plt.legend()
plt.show()

# %%
#堆叠条形图

import matplotlib.pyplot as plt
import numpy as np
# 返回一个终点为4的排列
index = np.arange(4) 
data1 = np.array([1,5,6,3])
data2 = np.array([1,2,1,5])
data3 = np.array([4,8,9,4])

a = 0.3
plt.title('multi bar chart')
# plt.barh()：横向的柱状图
plt.barh(index, data1, a, color = 'pink', label = 'a', hatch = '/')#柱子填充符号。
plt.barh(index, data2, a, left = data1,           # 堆叠在左边第一个上方
        color = 'c', label = 'b')
plt.barh(index, data3, a, left = (data1 + data2), # 堆叠在左边第一个和第二个上方
        color = 'orange', alpha = 0.5,label = 'c')

plt.legend()
plt.show()
