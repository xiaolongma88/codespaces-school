# %%
# %pip list
# Out:
# Package                  Version
# ------------------------ -----------
# anyio                    3.6.2
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# asttokens                2.2.0
# attrs                    22.1.0
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# certifi                  2022.9.24
# cffi                     1.15.1
# charset-normalizer       2.1.1
# colorama                 0.4.6
# contourpy                1.0.6
# cycler                   0.11.0
# debugpy                  1.6.4
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# executing                1.2.0
# fastjsonschema           2.16.2
# fonttools                4.38.0
# gitdb                    4.0.10
# GitPython                3.1.29
# idna                     3.4
# ipykernel                6.17.1
# ipython                  8.7.0
# ...

# %%
# %pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.5 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandasgui
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.2/218.2 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 66.2 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.1/360.1 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.4/230.4 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.9/34.9 MB 32.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.9/983.9 kB 27.5 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 6.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 20.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
from pandasgui import show
show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from pandasgui import show
#       2 show()
#
# File ~/.python/current/lib/python3.10/site-packages/pandasgui/__init__.py:15
#      12 logger.addHandler(sh)
#      14 # Imports
# ---> 15 from pandasgui.gui import show
#      17 __all__ = ["show", "__version__"]
#
# File ~/.python/current/lib/python3.10/site-packages/pandasgui/gui.py:9
#       7 from dataclasses import dataclass
#       8 import pandas as pd
# ----> 9 from PyQt5 import QtCore, QtGui, QtWidgets
#      10 from PyQt5.QtCore import Qt
#      12 import pandasgui
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
