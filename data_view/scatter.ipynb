# %%
import pandas as pd
import seaborn as sns

# %%
city_data = pd.read_csv('./data_set/city_data.csv')
city_data.head()

# %%
sns.scatterplot(x='GDP', y='people_shop', size='GDP', hue='city', data=city_data)
# Out:
# <AxesSubplot: xlabel='GDP', ylabel='people_shop'>

# %%
sns.scatterplot(x='GDP', y='people_shop', hue='city', data=city_data)
# Out:
# <AxesSubplot: xlabel='GDP', ylabel='people_shop'>
